# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pc = pd.read_csv('pc.csv')
ps4 = pd.read_csv('ps4.csv')

# %%
print(pc.shape)
pc.head()
# Out:
# (1407, 9)
#   platform                      title  meta_score user_score  num_critics  \
# 0       pc  DIVINITY: ORIGINAL SIN II        93.0        8.8         72.0
# 1       pc                   OKAMI HD        92.0        7.9         10.0
# 2       pc                  BAYONETTA        90.0        8.1         17.0
# 3       pc                    F1 2017        89.0        7.3         13.0
# 4       pc                  LONE ECHO        89.0        7.9         14.0
#
#       num_users                                           genres  \
# 0  2171 Ratings  ['Action RPG', 'Role-Playing', 'Western-Style']
# 1   209 Ratings                  ['Action Adventure', 'General']
# 2   541 Ratings                   ['Action Adventure', 'Linear']
# 3   102 Ratings           ['Racing', 'Simulation', 'Automobile']
# 4    77 Ratings                  ['Action Adventure', 'General']
#
#                           developer release_date
# 0              Larian Studios Games    14-Sep-17
# 1                            Capcom    12-Dec-17
# 2  PlatinumGames, Nex Entertainment    11-Apr-17
# 3                       Codemasters    24-Aug-17
# 4                     Ready at Dawn    20-Jul-17

# %%
print(ps4.shape)
ps4.head()
# Out:
# (1312, 9)
#   platform                          title  meta_score user_score  num_critics  \
# 0      ps4                      PERSONA 5          93        8.7           98
# 1      ps4                      UNDERTALE          92        7.1           18
# 2      ps4  FINAL FANTASY XIV: STORMBLOOD          89        8.6           15
# 3      ps4              HORIZON ZERO DAWN          89        8.4          115
# 4      ps4    WHAT REMAINS OF EDITH FINCH          88        8.3           65
#
#        num_users                                          genres  \
# 0   5184 Ratings              ['Role-Playing', 'Japanese-Style']
# 1    845 Ratings              ['Role-Playing', 'Japanese-Style']
# 2    331 Ratings       ['Role-Playing', 'Massively Multiplayer']
# 3  10589 Ratings                  ['Role-Playing', 'Action RPG']
# 4    749 Ratings  ['General', 'Adventure', '3D', 'First-Person']
#
#        developer release_date
# 0          Atlus     4-Apr-17
# 1   tobyfox, 8-4    15-Aug-17
# 2    Square Enix    20-Jun-17
# 3      Guerrilla    28-Feb-17
# 4  Giant Sparrow    25-Apr-17

# %% [markdown]
# ## Data Cleansing

# %%
# removing the string ' Ratings' from num_users column
pc.num_users = pc.num_users.str.strip(' Ratings')
ps4.num_users = ps4.num_users.str.strip(' Ratings')

# %%
# from genres column, removing ' "" [ ] characters
pc.genres = pc.genres.str.strip('[]')
pc.genres = pc.genres.str.replace("'","")
pc.genres = pc.genres.str.replace('"','')

ps4.genres = ps4.genres.str.strip('[]""')
ps4.genres = ps4.genres.str.replace("'","")
ps4.genres = ps4.genres.str.replace('"','')

# %%
# removing null values
pc.dropna(inplace=True)
ps4.dropna(inplace=True)

# %%
pc.dtypes
# Out:
# platform         object
# title            object
# meta_score      float64
# user_score       object
# num_critics     float64
# num_users        object
# genres           object
# developer        object
# release_date     object
# dtype: object

# %%
ps4.dtypes
# Out:
# platform        object
# title           object
# meta_score       int64
# user_score      object
# num_critics      int64
# num_users       object
# genres          object
# developer       object
# release_date    object
# dtype: object

# %%
# formatting the data types
pc.release_date = pd.to_datetime(pc.release_date)
pc.num_users = pc.num_users.astype(int)
pc.num_critics = pc.num_critics.astype(int)
pc.user_score = pc.user_score.astype(float)
pc.meta_score = pc.meta_score.astype(float)

ps4.release_date = pd.to_datetime(ps4.release_date)
ps4.num_users = ps4.num_users.astype(int)
ps4.num_critics = ps4.num_critics.astype(int)
ps4.user_score = ps4.user_score.astype(float)
ps4.meta_score = ps4.meta_score.astype(float)

# %%
pc.head()
# Out:
#   platform                      title  meta_score  user_score  num_critics  \
# 0       pc  DIVINITY: ORIGINAL SIN II        93.0         8.8           72
# 1       pc                   OKAMI HD        92.0         7.9           10
# 2       pc                  BAYONETTA        90.0         8.1           17
# 3       pc                    F1 2017        89.0         7.3           13
# 4       pc                  LONE ECHO        89.0         7.9           14
#
#    num_users                                   genres  \
# 0       2171  Action RPG, Role-Playing, Western-Style
# 1        209                Action Adventure, General
# 2        541                 Action Adventure, Linear
# 3        102           Racing, Simulation, Automobile
# 4         77                Action Adventure, General
#
#                           developer release_date
# 0              Larian Studios Games   2017-09-14
# 1                            Capcom   2017-12-12
# 2  PlatinumGames, Nex Entertainment   2017-04-11
# 3                       Codemasters   2017-08-24
# 4                     Ready at Dawn   2017-07-20

# %%
ps4.head()
# Out:
#   platform                          title  meta_score  user_score  \
# 0      ps4                      PERSONA 5        93.0         8.7
# 1      ps4                      UNDERTALE        92.0         7.1
# 2      ps4  FINAL FANTASY XIV: STORMBLOOD        89.0         8.6
# 3      ps4              HORIZON ZERO DAWN        89.0         8.4
# 4      ps4    WHAT REMAINS OF EDITH FINCH        88.0         8.3
#
#    num_critics  num_users                                genres  \
# 0           98       5184          Role-Playing, Japanese-Style
# 1           18        845          Role-Playing, Japanese-Style
# 2           15        331   Role-Playing, Massively Multiplayer
# 3          115      10589              Role-Playing, Action RPG
# 4           65        749  General, Adventure, 3D, First-Person
#
#        developer release_date
# 0          Atlus   2017-04-04
# 1   tobyfox, 8-4   2017-08-15
# 2    Square Enix   2017-06-20
# 3      Guerrilla   2017-02-28
# 4  Giant Sparrow   2017-04-25

# %% [markdown]
# ### Creating a new dataset that contains games published on both platforms

# %%
# keeping only the games published on both platforms
pc_1 = pc[pc.title.isin(ps4.title)]
ps4_1 = ps4[ps4.title.isin(pc.title)]

# %%
# merging those two dfs
pc_ps4 = pd.concat([pc_1,ps4_1]).sort_values(by=['title','platform'], ascending=True).reset_index(drop=True)

# %%
pc_ps4.head()
# Out:
#   platform                    title  meta_score  user_score  num_critics  \
# 0       pc  .HACK//G.U. LAST RECODE        69.0         8.1            7
# 1      ps4  .HACK//G.U. LAST RECODE        76.0         8.1           21
# 2       pc   11-11: MEMORIES RETOLD        73.0         6.7           11
# 3      ps4   11-11: MEMORIES RETOLD        77.0         7.7           33
# 4       pc                     198X        63.0         5.5           13
#
#    num_users                                             genres  \
# 0         27                         Miscellaneous, Compilation
# 1         68                         Miscellaneous, Compilation
# 2         29               Adventure, General, 3D, Third-Person
# 3         57               Adventure, General, 3D, Third-Person
# 4         21  Action, Miscellaneous, Platformer, Party / Min...
#
#                 developer release_date
# 0           CyberConnect2   2017-11-03
# 1           CyberConnect2   2017-11-03
# 2  Digixart Entertainment   2018-11-08
# 3  Digixart Entertainment   2018-11-09
# 4          Hi-Bit Studios   2019-06-20

# %%
# saving cleaned datasets
pc_ps4.to_csv('pc_ps4.csv', index=False)
pc.to_csv('pc_cleaned.csv', index=False)
ps4.to_csv('ps4_cleaned.csv', index=False)
